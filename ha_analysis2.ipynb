# %% [markdown]
# # Plots and analysis

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import seaborn as sns
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import pingouin as pg

from functions import sig, alter_sig, sigfit, alter_sigfit

pd.options.mode.chained_assignment = None  # Stop seeing warnings

# %%
df = pd.read_pickle("data/df")
df_sigmoid = pd.read_pickle("data/df_sigmoid")

# %%
def profile_participants(group, aq_mc):
    if group == "HA" and aq_mc:
        profile = "2e"

    elif group == "HA":
        profile = "HA"

    elif group == "Control" and aq_mc:
        profile = "H-AQ"

    elif group == "Control" and not aq_mc:
        profile = "TD"

    else:
        profile = None

    return profile


df["Profile"] = df.apply(
    lambda x: profile_participants(group=x["Group"], aq_mc=x["AQ_MC"]), axis=1
)
df
# Out:
#    Código de participante    Group        Sex   Age                        EL  \
# 7                    AC01       HA   Femenino  17.0  Universitario incompleto
# 8                    AC02       HA   Femenino  16.0  Universitario incompleto
# 9                    AC03       HA   Femenino  17.0       Secundaria completa
# 11                   AC05       HA   Femenino  16.0  Universitario incompleto
# 12                   AC06       HA   Femenino  17.0  Universitario incompleto
# 14                   AC08       HA  Masculino  18.0  Universitario incompleto
# 15                   AC09       HA  Masculino  17.0       Secundaria completa
# 16                   AC10       HA   Femenino  18.0       Secundaria completa
# 17                   AC11       HA  Masculino  17.0  Universitario incompleto
# 20                   AC14       HA   Femenino  17.0  Universitario incompleto
# 23                   AC17       HA   Femenino  16.0  Universitario incompleto
# 25                   AC19       HA   Femenino  17.0  Universitario incompleto
# 26                   AC20       HA   Femenino  16.0       Secundaria completa
# 27                   AC21       HA  Masculino  17.0  Universitario incompleto
# 28                   AC22       HA   Femenino  16.0       Secundaria completa
# 36                   AC30       HA  Masculino  17.0  Universitario incompleto
# 38                   AC32       HA   Femenino  17.0       Secundaria completa
# 39                   AC33       HA   Femenino  18.0       Secundaria completa
# 40                   AC34       HA   Femenino  18.0       Secundaria completa
# 45                   AC39       HA   Femenino  18.0  Universitario incompleto
# 46                   AC40       HA  Masculino  18.0       Secundaria completa
# 47                   AC41       HA   Femenino  18.0  Universitario incompleto
# 48                   AC42       HA   Femenino  18.0  Universitario incompleto
# 49                   AC43       HA   Femenino  18.0  Universitario incompleto
# 51                  GC001  Control   Femenino  18.0       Secundaria completa
# 54                  GC004  Control   Femenino  19.0  Universitario incompleto
# 56                  GC006  Control   Femenino  21.0  Universitario incompleto
# 57                  GC007  Control   Femenino  19.0       Secundaria completa
# 58                  GC008  Control   Femenino  19.0  Universitario incompleto
# 60                  GC010  Control   Femenino  19.0       Secundaria completa
# 62                  GC012  Control   Femenino  19.0  Universitario incompleto
#
#                   Occupation                             Scholarship  \
# 7                 Estudiante                                     NaN
# 8   Estudiante de ingeniería                                     NaN
# 9                 Estudiante                                     NaN
# 11                Estudiante                                     NaN
# 12                estudiante                                     NaN
# 14                Estudiante                                     NaN
# 15               Estudiante                                      NaN
# 16                Estudiante                                     NaN
# 17                Estudiante                                     NaN
# 20                Estudiante                                     NaN
# 23                Estudiante                                     NaN
# 25  Estudiante universitario                                     NaN
# 26  Estudiante universitaria                                     NaN
# 27                Estudiante                                     NaN
# 28                Estudiante                                     NaN
# 36          Ingeniería Civil                                     NaN
# 38                Estudiante                         Sí, becas Lucet
# 39                Estudiante                  Si, Becas Lucet (PUCP)
# 40                Estudiante                              Beca Lucet
# 45             Universitario                         Sí, Becas Lucet
# 46                Estudiante  Si, soy beneficiario de la beca Lucet.
# 47                Estudiante                             Becas Lucet
# 48                Estudiante                              Beca Lucet
# 49                estudiante                             Becas Lucet
# 51                Estudiante                                  BECA18
# 54                Estudiante               RPU-Movilidad Estudiantil
# 56                Estudiante                             Sí, beca 18
# 57                Estudiante                                      No
# 58                estudiante                                      no
# 60                Estudiante                                 BECA 18
# 62                Estudiante                                 Beca 18
#
#    Neurological_D Conditions Prob_Vision  ... HL_500 HL_1000 HL_2000 HL_4000  \
# 7              No         No          No  ...   10.0    10.0    10.0    15.0
# 8              No         No          Si  ...    5.0    10.0     5.0    10.0
# 9              No         No          No  ...   10.0     5.0     5.0     5.0
# 11             No         No          No  ...    5.0     0.0     5.0     5.0
# 12             No         No          No  ...    5.0     5.0    -5.0     0.0
# 14             No         No          No  ...    0.0     0.0     0.0     5.0
# 15             No         No          Si  ...   15.0    10.0     5.0     5.0
# 16             No         No          No  ...   15.0     5.0    10.0     5.0
# 17             No         No          Si  ...   10.0     5.0    10.0    15.0
# 20             No         No          No  ...    5.0    10.0    10.0     0.0
# 23             No         No          No  ...   10.0    15.0     5.0    10.0
# 25             No         No          No  ...    0.0     0.0     0.0     0.0
# 26             No         No          No  ...   15.0    15.0    10.0     0.0
# 27             No         No          No  ...   -5.0     0.0     0.0    -5.0
# 28             No         No          Si  ...    5.0    15.0     0.0     0.0
# 36             No         No          No  ...   15.0    15.0    15.0     5.0
# 38             No         No          No  ...   25.0    25.0    10.0    10.0
# 39             No         No          Si  ...    NaN     NaN     NaN     NaN
# 40             No         No          Si  ...    0.0     5.0     5.0     0.0
# 45             No         No          No  ...    0.0     0.0     0.0     0.0
# 46             No         No          No  ...    NaN     NaN     NaN     NaN
# 47             No         No          Si  ...    NaN     NaN     NaN     NaN
# 48             No         No          Si  ...   10.0     5.0     5.0     0.0
# 49             No         No          Si  ...    0.0    -5.0     0.0    -5.0
# 51             No         No          No  ...    0.0     0.0     0.0    -5.0
# 54             No         No          Si  ...   15.0     0.0     5.0     0.0
# 56             No         No          No  ...    5.0     0.0     5.0     0.0
# 57             No         No          Si  ...    0.0    -5.0     5.0    -5.0
# 58             No         No          No  ...    5.0     0.0     5.0     5.0
# 60             No         No          No  ...    5.0     5.0    -5.0     0.0
# 62             No         No          Si  ...    5.0    10.0     0.0    10.0
#
#    HL_8000     Avg_LDL   Avg_HL_L   Avg_HL_R     Avg_HL  Profile
# 7     20.0   60.833333  12.500000  15.000000  12.500000       HA
# 8     15.0   87.500000   9.166667  11.666667   9.166667       2e
# 9      5.0   94.166667   6.666667   7.500000   6.666667       HA
# 11     5.0   93.333333   4.166667   5.000000   4.166667       2e
# 12   -10.0  105.000000   0.000000   1.666667   0.000000       2e
# 14   -10.0   75.833333   0.000000   2.500000   0.000000       HA
# 15     5.0   98.750000  12.500000   8.333333   8.333333       HA
# 16     0.0   95.416667  13.333333   8.333333   8.333333       2e
# 17    -5.0   84.166667   7.500000   9.166667   7.500000       2e
# 20   -10.0  105.833333   5.000000   3.333333   3.333333       2e
# 23     0.0   51.666667   9.166667   8.333333   8.333333       HA
# 25     0.0   46.666667   1.666667  -0.833333  -0.833333       HA
# 26     0.0  103.750000  11.666667  10.000000  10.000000       2e
# 27     5.0   87.500000  -0.833333   0.833333  -0.833333       HA
# 28    10.0   66.666667  10.833333   6.666667   6.666667       HA
# 36    10.0   75.000000  11.666667  11.666667  11.666667       HA
# 38    15.0  106.666667  17.500000  18.333333  18.333333       HA
# 39     NaN         NaN        NaN        NaN        NaN       HA
# 40   -10.0   55.000000   0.000000   2.500000   0.000000       HA
# 45     0.0   94.166667   0.000000   1.666667   0.000000       2e
# 46     NaN         NaN        NaN        NaN        NaN       2e
# 47     NaN         NaN        NaN        NaN        NaN       2e
# 48    -5.0   83.333333   3.333333  10.000000   3.333333       HA
# 49     0.0   68.333333  -2.500000   0.000000  -2.500000       HA
# 51   -10.0   40.000000  -1.666667   0.833333  -1.666667       TD
# 54     0.0   36.666667   9.166667   5.000000   5.000000     H-AQ
# 56    15.0   37.500000  10.833333   5.000000   5.000000       TD
# 57     0.0   72.500000  -1.666667   1.666667  -1.666667       TD
# 58     5.0   38.333333   4.166667   6.666667   4.166667       TD
# 60     0.0   36.666667   4.166667   1.666667   1.666667       TD
# 62     5.0   80.833333  10.833333   6.666667   6.666667     H-AQ
#
# [31 rows x 65 columns]

# %%
df.describe()
# Out:
#              Age   AQ_TOTAL  AQ_Attention_Detail  AQ_Attention_Switch  \
# count  31.000000  31.000000            31.000000            31.000000
# mean   17.612903   4.741935             1.419355             1.064516
# std     1.145351   1.692488             0.922829             0.727346
# min    16.000000   1.000000             0.000000             0.000000
# 25%    17.000000   4.000000             0.000000             1.000000
# 50%    18.000000   5.000000             2.000000             1.000000
# 75%    18.000000   6.000000             2.000000             2.000000
# max    21.000000   8.000000             2.000000             2.000000
#
#        AQ_Communication  AQ_Imagination  AQ_Social       AQ_1       AQ_2  \
# count         31.000000       31.000000  31.000000  31.000000  31.000000
# mean           1.290323        0.709677   1.000000   0.709677   0.387097
# std            0.692510        0.642575   0.516398   0.461414   0.495138
# min            0.000000        0.000000   0.000000   0.000000   0.000000
# 25%            1.000000        0.000000   1.000000   0.000000   0.000000
# 50%            1.000000        1.000000   1.000000   1.000000   0.000000
# 75%            2.000000        1.000000   1.000000   1.000000   1.000000
# max            2.000000        2.000000   2.000000   1.000000   1.000000
#
#             AQ_3  ...     HL_250     HL_500    HL_1000    HL_2000    HL_4000  \
# count  31.000000  ...  28.000000  28.000000  28.000000  28.000000  28.000000
# mean    0.709677  ...   6.785714   6.785714   5.714286   4.285714   3.035714
# std     0.461414  ...   6.833237   6.696362   7.033555   4.852316   5.666550
# min     0.000000  ...  -5.000000  -5.000000  -5.000000  -5.000000  -5.000000
# 25%     0.000000  ...   5.000000   0.000000   0.000000   0.000000   0.000000
# 50%     1.000000  ...   5.000000   5.000000   5.000000   5.000000   0.000000
# 75%     1.000000  ...  10.000000  10.000000  10.000000   6.250000   5.000000
# max     1.000000  ...  25.000000  25.000000  25.000000  15.000000  15.000000
#
#          HL_8000     Avg_LDL   Avg_HL_L   Avg_HL_R     Avg_HL
# count  28.000000   28.000000  28.000000  28.000000  28.000000
# mean    1.964286   74.360119   6.041667   6.041667   4.761905
# std     8.315457   23.729681   5.627429   4.733782   5.085975
# min   -10.000000   36.666667  -2.500000  -0.833333  -2.500000
# 25%    -1.250000   54.166667   0.000000   1.666667   0.000000
# 50%     0.000000   78.333333   5.833333   5.833333   4.583333
# 75%     5.000000   94.166667  10.833333   8.541667   8.333333
# max    20.000000  106.666667  17.500000  18.333333  18.333333
#
# [8 rows x 47 columns]

# %%
df.groupby(["Group", "Sex"]).count()
# Out:
#                    Código de participante  Age  EL  Occupation  Scholarship  \
# Group   Sex
# Control Femenino                        7    7   7           7            7
# HA      Femenino                       18   18  18          18            7
#         Masculino                       6    6   6           6            1
#
#                    Neurological_D  Conditions  Prob_Vision  Prob_Aud  \
# Group   Sex
# Control Femenino                7           7            7         7
# HA      Femenino               18          18           18        18
#         Masculino               6           6            6         6
#
#                    Psiq_diag  ...  HL_500  HL_1000  HL_2000  HL_4000  HL_8000  \
# Group   Sex                   ...
# Control Femenino           7  ...       7        7        7        7        7
# HA      Femenino          18  ...      16       16       16       16       16
#         Masculino          6  ...       5        5        5        5        5
#
#                    Avg_LDL  Avg_HL_L  Avg_HL_R  Avg_HL  Profile
# Group   Sex
# Control Femenino         7         7         7       7        7
# HA      Femenino        16        16        16      16       18
#         Masculino        5         5         5       5        6
#
# [3 rows x 63 columns]

# %%
df.groupby(["Profile", "Sex"]).count()
# Out:
#                    Código de participante  Group  Age  EL  Occupation  \
# Profile Sex
# 2e      Femenino                        8      8    8   8           8
#         Masculino                       2      2    2   2           2
# H-AQ    Femenino                        2      2    2   2           2
# HA      Femenino                       10     10   10  10          10
#         Masculino                       4      4    4   4           4
# TD      Femenino                        5      5    5   5           5
#
#                    Scholarship  Neurological_D  Conditions  Prob_Vision  \
# Profile Sex
# 2e      Femenino             2               8           8            8
#         Masculino            1               2           2            2
# H-AQ    Femenino             2               2           2            2
# HA      Femenino             5              10          10           10
#         Masculino            0               4           4            4
# TD      Femenino             5               5           5            5
#
#                    Prob_Aud  ...  HL_250  HL_500  HL_1000  HL_2000  HL_4000  \
# Profile Sex                  ...
# 2e      Femenino          8  ...       7       7        7        7        7
#         Masculino         2  ...       1       1        1        1        1
# H-AQ    Femenino          2  ...       2       2        2        2        2
# HA      Femenino         10  ...       9       9        9        9        9
#         Masculino         4  ...       4       4        4        4        4
# TD      Femenino          5  ...       5       5        5        5        5
#
#                    HL_8000  Avg_LDL  Avg_HL_L  Avg_HL_R  Avg_HL
# Profile Sex
# 2e      Femenino         7        7         7         7       7
#         Masculino        1        1         1         1       1
# H-AQ    Femenino         2        2         2         2       2
# HA      Femenino         9        9         9         9       9
#         Masculino        4        4         4         4       4
# TD      Femenino         5        5         5         5       5
#
# [6 rows x 63 columns]

# %% [markdown]
# ## Comparing means of LDL and HL between HA and control across frequencies
# - T-test LDL per group per frequency
# - LDL mean per group per frequency (pointplot)
# - LDL mean per group per frequency (boxplot)
# - T-test HL per group per frequency
# - HL mean per group per frequency (pointplot)
# - HL mean per group per frequency (boxplot)

# %% [markdown]
# ### Preprocessing for this area

# %%
df = df[
    [
        "Código de participante",
        "Group",
        "TWI",
        "OPI",
        "LDL_250",
        "LDL_500",
        "LDL_1000",
        "LDL_2000",
        "LDL_4000",
        "LDL_8000",
        "LDL_Ear",
        "HL_250_R",
        "HL_500_R",
        "HL_1000_R",
        "HL_2000_R",
        "HL_4000_R",
        "HL_8000_R",
        "HL_250_L",
        "HL_500_L",
        "HL_1000_L",
        "HL_2000_L",
        "HL_4000_L",
        "HL_8000_L",
        "HL_250",
        "HL_500",
        "HL_1000",
        "HL_2000",
        "HL_4000",
        "HL_8000",
        "Avg_LDL",
        "Avg_HL_L",
        "Avg_HL_R",
        "Avg_HL",
        "AQ_TOTAL",
        "Profile",
    ]
]

# %% [markdown]
# Cannot run with NaN values, so I will drop them by now. However, in the oficial running, Nan participants should be eliminated by now and thus the following cell shouldnt run

# %%
df.dropna(inplace=True)
df.sample(10)
# Out:
#    Código de participante    Group         TWI       OPI  LDL_250  LDL_500  \
# 17                   AC11       HA  121.067219  0.140000     65.0     90.0
# 40                   AC34       HA  101.080018  0.146667     60.0     70.0
# 11                   AC05       HA  145.791619  0.493333     80.0     95.0
# 20                   AC14       HA  145.366310  0.020000     80.0    100.0
# 14                   AC08       HA  114.249866  0.306667     80.0     75.0
# 51                  GC001  Control  190.209289  0.693333     40.0     45.0
# 45                   AC39       HA  173.812315  0.080000     95.0    100.0
# 12                   AC06       HA  228.092147  0.473333     80.0    100.0
# 27                   AC21       HA  135.635317  0.320000     80.0     75.0
# 57                  GC007  Control   96.582238  0.226667     65.0     75.0
#
#     LDL_1000  LDL_2000  LDL_4000  LDL_8000  ... HL_1000  HL_2000  HL_4000  \
# 17      90.0      90.0      90.0      80.0  ...     5.0     10.0     15.0
# 40      80.0      50.0      45.0      25.0  ...     5.0      5.0      0.0
# 11     100.0     105.0     100.0      80.0  ...     0.0      5.0      5.0
# 20     120.0     120.0     115.0     100.0  ...    10.0     10.0      0.0
# 14      75.0      80.0      80.0      65.0  ...     0.0      0.0      5.0
# 51      45.0      50.0      40.0      20.0  ...     0.0      0.0     -5.0
# 45      95.0      80.0      95.0     100.0  ...     0.0      0.0      0.0
# 12     120.0     115.0     115.0     100.0  ...     5.0     -5.0      0.0
# 27      95.0      90.0      90.0      95.0  ...     0.0      0.0     -5.0
# 57      70.0      75.0      75.0      75.0  ...    -5.0      5.0     -5.0
#
#     HL_8000     Avg_LDL  Avg_HL_L  Avg_HL_R    Avg_HL  AQ_TOTAL  Profile
# 17     -5.0   84.166667  7.500000  9.166667  7.500000       6.0       2e
# 40    -10.0   55.000000  0.000000  2.500000  0.000000       4.0       HA
# 11      5.0   93.333333  4.166667  5.000000  4.166667       7.0       2e
# 20    -10.0  105.833333  5.000000  3.333333  3.333333       8.0       2e
# 14    -10.0   75.833333  0.000000  2.500000  0.000000       3.0       HA
# 51    -10.0   40.000000 -1.666667  0.833333 -1.666667       1.0       TD
# 45      0.0   94.166667  0.000000  1.666667  0.000000       6.0       2e
# 12    -10.0  105.000000  0.000000  1.666667  0.000000       7.0       2e
# 27      5.0   87.500000 -0.833333  0.833333 -0.833333       4.0       HA
# 57      0.0   72.500000 -1.666667  1.666667 -1.666667       4.0       TD
#
# [10 rows x 35 columns]

# %% [markdown]
# ### Loudness Discomfort Level (LDL) between groups

# %% [markdown]
# #### Preprocessing for these plots

# %%
df_pointplots = df[
    [
        "Código de participante",
        "Group",
        "LDL_250",
        "LDL_500",
        "LDL_1000",
        "LDL_2000",
        "LDL_4000",
        "LDL_8000",
        "LDL_Ear",
        "HL_250_R",
        "HL_500_R",
        "HL_1000_R",
        "HL_2000_R",
        "HL_4000_R",
        "HL_8000_R",
        "HL_250_L",
        "HL_500_L",
        "HL_1000_L",
        "HL_2000_L",
        "HL_4000_L",
        "HL_8000_L",
        "HL_250",
        "HL_500",
        "HL_1000",
        "HL_2000",
        "HL_4000",
        "HL_8000",
        "AQ_TOTAL",
        "Profile",
    ]
]

# %%
# Split groups
df_pointplots_HA = df_pointplots[df_pointplots["Group"] == "HA"]
df_pointplots_control = df_pointplots[df_pointplots["Group"] == "Control"]

# Melt for HA
df_pointplots_HA = pd.melt(
    df_pointplots_HA,
    id_vars=["Código de participante", "AQ_TOTAL", "Profile"],
    value_vars=["LDL_250", "LDL_500", "LDL_1000", "LDL_2000", "LDL_4000", "LDL_8000"],
)
df_pointplots_HA["Group"] = "HA"

# Melt for control
df_pointplots_control = pd.melt(
    df_pointplots_control,
    id_vars=["Código de participante", "AQ_TOTAL", "Profile"],
    value_vars=["LDL_250", "LDL_500", "LDL_1000", "LDL_2000", "LDL_4000", "LDL_8000"],
)
df_pointplots_control["Group"] = "Control"

# Concat
df_pointplots_ldl = pd.concat([df_pointplots_HA, df_pointplots_control])

df_pointplots_ldl
# Out:
#    Código de participante  AQ_TOTAL Profile  variable  value    Group
# 0                    AC01       5.0      HA   LDL_250   60.0       HA
# 1                    AC02       6.0      2e   LDL_250   80.0       HA
# 2                    AC03       5.0      HA   LDL_250   80.0       HA
# 3                    AC05       7.0      2e   LDL_250   80.0       HA
# 4                    AC06       7.0      2e   LDL_250   80.0       HA
# ..                    ...       ...     ...       ...    ...      ...
# 31                  GC006       2.0      TD  LDL_8000   35.0  Control
# 32                  GC007       4.0      TD  LDL_8000   75.0  Control
# 33                  GC008       4.0      TD  LDL_8000   20.0  Control
# 34                  GC010       4.0      TD  LDL_8000   35.0  Control
# 35                  GC012       6.0    H-AQ  LDL_8000   75.0  Control
#
# [138 rows x 6 columns]

# %%
# Rename columns
df_pointplots_ldl.columns = ["ID", "AQ", "Profile", "Frequency", "Db", "Group"]
df_pointplots_ldl
# Out:
#        ID   AQ Profile Frequency    Db    Group
# 0    AC01  5.0      HA   LDL_250  60.0       HA
# 1    AC02  6.0      2e   LDL_250  80.0       HA
# 2    AC03  5.0      HA   LDL_250  80.0       HA
# 3    AC05  7.0      2e   LDL_250  80.0       HA
# 4    AC06  7.0      2e   LDL_250  80.0       HA
# ..    ...  ...     ...       ...   ...      ...
# 31  GC006  2.0      TD  LDL_8000  35.0  Control
# 32  GC007  4.0      TD  LDL_8000  75.0  Control
# 33  GC008  4.0      TD  LDL_8000  20.0  Control
# 34  GC010  4.0      TD  LDL_8000  35.0  Control
# 35  GC012  6.0    H-AQ  LDL_8000  75.0  Control
#
# [138 rows x 6 columns]

# %%
pg.mixed_anova(
    data=df_pointplots_ldl, dv="Db", between="Group", within="Frequency", subject="ID"
)
# Out:
#         Source            SS  DF1  DF2            MS         F     p-unc  \
# 0        Group  22269.609619    1   21  22269.609619  9.747525  0.005154
# 1    Frequency   2759.601449    5  105    551.920290  6.403697  0.000031
# 2  Interaction    103.184498    5  105     20.636900  0.239441  0.944172
#
#    p-GG-corr       np2       eps sphericity   W-spher   p-spher
# 0        NaN  0.317018       NaN        NaN       NaN       NaN
# 1   0.000318  0.233680  0.665449      False  0.305624  0.049448
# 2        NaN  0.011273       NaN        NaN       NaN       NaN

# %%
ldl_posthoc = pg.pairwise_tests(
    data=df_pointplots_ldl,
    dv="Db",
    between="Group",
    within="Frequency",
    subject="ID",
    correction=True,
    effsize="cohen",
    padjust="bonferroni",
)
ldl_posthoc
# Out:
#              Contrast Frequency         A         B Paired Parametric  \
# 0           Frequency         -  LDL_1000  LDL_2000   True       True
# 1           Frequency         -  LDL_1000   LDL_250   True       True
# 2           Frequency         -  LDL_1000  LDL_4000   True       True
# 3           Frequency         -  LDL_1000   LDL_500   True       True
# 4           Frequency         -  LDL_1000  LDL_8000   True       True
# 5           Frequency         -  LDL_2000   LDL_250   True       True
# 6           Frequency         -  LDL_2000  LDL_4000   True       True
# 7           Frequency         -  LDL_2000   LDL_500   True       True
# 8           Frequency         -  LDL_2000  LDL_8000   True       True
# 9           Frequency         -   LDL_250  LDL_4000   True       True
# 10          Frequency         -   LDL_250   LDL_500   True       True
# 11          Frequency         -   LDL_250  LDL_8000   True       True
# 12          Frequency         -  LDL_4000   LDL_500   True       True
# 13          Frequency         -  LDL_4000  LDL_8000   True       True
# 14          Frequency         -   LDL_500  LDL_8000   True       True
# 15              Group         -   Control        HA  False       True
# 16  Frequency * Group  LDL_1000   Control        HA  False       True
# 17  Frequency * Group  LDL_2000   Control        HA  False       True
# 18  Frequency * Group   LDL_250   Control        HA  False       True
# 19  Frequency * Group  LDL_4000   Control        HA  False       True
# 20  Frequency * Group   LDL_500   Control        HA  False       True
# 21  Frequency * Group  LDL_8000   Control        HA  False       True
#
#            T        dof alternative     p-unc    p-corr    p-adjust     BF10  \
# 0   2.098094  22.000000   two-sided  0.047602  0.714030  bonferroni    1.373
# 1   5.011512  22.000000   two-sided  0.000051  0.000769  bonferroni  496.859
# 2   1.997685  22.000000   two-sided  0.058264  0.873955  bonferroni    1.172
# 3   2.205762  22.000000   two-sided  0.038147  0.572211  bonferroni    1.637
# 4   3.758864  22.000000   two-sided  0.001084  0.016260  bonferroni   33.015
# 5   2.752257  22.000000   two-sided  0.011627  0.174406  bonferroni    4.326
# 6   0.743138  22.000000   two-sided  0.465261  1.000000  bonferroni    0.281
# 7   0.173009  22.000000   two-sided  0.864227  1.000000  bonferroni    0.222
# 8   3.108954  22.000000   two-sided  0.005117  0.076753  bonferroni    8.645
# 9  -1.868407  22.000000   two-sided  0.075081  1.000000  bonferroni    0.964
# 10 -3.510229  22.000000   two-sided  0.001975  0.029625  bonferroni   19.588
# 11  0.070045  22.000000   two-sided  0.944790  1.000000  bonferroni    0.219
# 12 -0.389142  22.000000   two-sided  0.700912  1.000000  bonferroni    0.234
# 13  2.921384  22.000000   two-sided  0.007907  0.118608  bonferroni    5.978
# 14  2.612046  22.000000   two-sided  0.015915  0.238722  bonferroni    3.333
# 15 -3.060590   8.508842   two-sided  0.014473       NaN         NaN     7.34
# 16 -3.635631   9.923245   two-sided  0.004628  0.027766  bonferroni   20.248
# 17 -3.008657   9.882601   two-sided  0.013315  0.079892  bonferroni    6.729
# 18 -3.461618   8.352264   two-sided  0.008000  0.048001  bonferroni    14.76
# 19 -2.117475   7.644264   two-sided  0.068682  0.412092  bonferroni    1.774
# 20 -3.154005   8.213315   two-sided  0.013073  0.078438  bonferroni    8.602
# 21 -2.605379   8.724431   two-sided  0.029203  0.175221  bonferroni    3.537
#
#        cohen
# 0   0.191797
# 1   0.614128
# 2   0.237427
# 3   0.224552
# 4   0.496691
# 5   0.353415
# 6   0.055921
# 7   0.018068
# 8   0.298179
# 9  -0.261531
# 10 -0.360824
# 11  0.009120
# 12 -0.042000
# 13  0.227974
# 14  0.296862
# 15 -1.482556
# 16 -1.622178
# 17 -1.345134
# 18 -1.695412
# 19 -1.097718
# 20 -1.560600
# 21 -1.243962

# %%
fig = sns.lmplot(x="AQ", y="Db", hue="Group", col="Frequency", data=df_pointplots_ldl)
plt.plot()
fig.savefig("drafts/gifted/FIG2.eps", bbox_inches="tight", format="eps")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
sns.boxplot(x="ID", y="Db", data=df_pointplots_ldl)
# Out:
# <Axes: xlabel='ID', ylabel='Db'>

# %%
sns.boxplot(x="Frequency", y="Db", data=df_pointplots_ldl)
# Out:
# <Axes: xlabel='Frequency', ylabel='Db'>

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# library(lme4) #Requires Matrix==1.6-5
# library(jtools)
# library(equatiomatic)

# %%
# %%R -i df_pointplots_ldl
#
# # Maximal random structure
# model <- lmer(Db ~ Group + Frequency + AQ + (1 + Group|ID) + (1 + Group|Frequency) + (1 + AQ|ID) + (1 + AQ|Frequency), data=df_pointplots_ldl, REML=FALSE)
# null_model <- lmer(Db ~ Frequency + AQ + (1 + Group|ID) + (1 + Group|Frequency) + (1 + AQ|ID) + (1 + AQ|Frequency), data=df_pointplots_ldl, REML=FALSE)
# #anova(model,null_model)
# summ(model)#, confint = TRUE, conf.method = "profile")
#
# #eq = extract_eq(model, wrap=TRUE, terms_per_line = 2, operator_location = "start")
# #eq
# Out:
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/rpy2/robjects/pandas2ri.py:56: UserWarning: DataFrame contains duplicated elements in the index, which will lead to loss of the row names in the resulting data.frame
#   warnings.warn('DataFrame contains duplicated elements in the index, '
# MODEL INFO:
# Observations: 138
# Dependent Variable: Db
# Type: Mixed effects linear regression
#
# MODEL FIT:
# AIC = 1092.98, BIC = 1154.45
# Pseudo-R² (fixed effects) = 0.51
# Pseudo-R² (total) = 0.89
#
# FIXED EFFECTS:
# --------------------------------------------------------------------
#                             Est.    S.E.   t val.        d.f.      p
# ----------------------- -------- ------- -------- ----------- ------
# (Intercept)                29.95   16.51     1.81        4.31   0.14
# GroupHA                    14.75   11.38     1.30        3.06   0.28
# FrequencyLDL_2000          -4.55   12.37    -0.37   450367.86   0.71
# FrequencyLDL_250          -12.61   12.37    -1.02   450367.86   0.31
# FrequencyLDL_4000          -6.04   12.37    -0.49   450367.86   0.63
# FrequencyLDL_500           -5.06   12.37    -0.41   450367.86   0.68
# FrequencyLDL_8000         -12.59   12.37    -1.02   450367.86   0.31
# AQ                          8.55    2.74     3.12        3.39   0.04
# --------------------------------------------------------------------
#
# p values calculated using Kenward-Roger standard errors and d.f.
#
# RANDOM EFFECTS:
# ---------------------------------------
#     Group       Parameter    Std. Dev.
# ------------- ------------- -----------
#      ID        (Intercept)     32.01
#      ID            AQ          4.04
#     ID.1       (Intercept)     0.01
#     ID.1         GroupHA       0.01
#   Frequency    (Intercept)     5.52
#   Frequency        AQ          1.23
#  Frequency.1   (Intercept)     0.00
#  Frequency.1     GroupHA       0.00
#   Residual                     8.59
# ---------------------------------------
#
# Grouping variables:
# -----------------------------
#    Group     # groups   ICC
# ----------- ---------- ------
#     ID          23      0.91
#  Frequency      6       0.00
# -----------------------------
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')

# %%
# %%R -i df_pointplots_ldl
#
# # Maximal random structure
# model <- lmer(Db ~ Group + Frequency + AQ + (1 + Group|ID) + (1 + Group|Frequency) + (1 + AQ|ID) + (1 + AQ|Frequency), data=df_pointplots_ldl, REML=FALSE)
# null_model <- lmer(Db ~ Frequency + AQ + (1 + Group|ID) + (1 + Group|Frequency) + (1 + AQ|ID) + (1 + AQ|Frequency), data=df_pointplots_ldl, REML=FALSE)
# anova(model,null_model)
# Out:
# Data: df_pointplots_ldl
# Models:
# null_model: Db ~ Frequency + AQ + (1 + Group | ID) + (1 + Group | Frequency) + (1 + AQ | ID) + (1 + AQ | Frequency)
# model: Db ~ Group + Frequency + AQ + (1 + Group | ID) + (1 + Group | Frequency) + (1 + AQ | ID) + (1 + AQ | Frequency)
#            npar    AIC    BIC  logLik deviance  Chisq Df Pr(>Chisq)
# null_model   20 1095.2 1153.7 -527.59   1055.2
# model        21 1093.0 1154.5 -525.49   1051.0 4.1905  1    0.04065 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')

# %%
# Explore based on :
# https://jontalle.web.engr.illinois.edu/MISC/lme4/bw_LME_tutorial.pdf
# - https://mypage.concordia.ca/faculty/pperesne/BIOL_422_680/L17_Slides.pdf
# - https://stats.stackexchange.com/questions/476176/difference-between-repeated-measures-anova-ancova-and-linear-mixed-effects-mode
# - https://stats.stackexchange.com/questions/13166/rs-lmer-cheat-sheet

# %% [markdown]
# #### Plots

# %%
df_pointplots_ldl.dropna()
# Out:
#        ID   AQ Profile Frequency    Db    Group
# 0    AC01  5.0      HA   LDL_250  60.0       HA
# 1    AC02  6.0      2e   LDL_250  80.0       HA
# 2    AC03  5.0      HA   LDL_250  80.0       HA
# 3    AC05  7.0      2e   LDL_250  80.0       HA
# 4    AC06  7.0      2e   LDL_250  80.0       HA
# ..    ...  ...     ...       ...   ...      ...
# 31  GC006  2.0      TD  LDL_8000  35.0  Control
# 32  GC007  4.0      TD  LDL_8000  75.0  Control
# 33  GC008  4.0      TD  LDL_8000  20.0  Control
# 34  GC010  4.0      TD  LDL_8000  35.0  Control
# 35  GC012  6.0    H-AQ  LDL_8000  75.0  Control
#
# [138 rows x 6 columns]

# %%
sns.set_context("talk")

fig = sns.pointplot(
    data=df_pointplots_ldl,
    x="Frequency",
    y="Db",
    hue="Group",
    linestyles=["-", "--"],
    errorbar="se",
    dodge=True,
)
fig.spines["top"].set_visible(False)
fig.spines["right"].set_visible(False)
fig.set_xticklabels([250, 500, 1000, 2000, 4000, 8000])
fig.set_ylabel(
    "Loudness Discomfort Level (Db)", fontdict={"weight": "bold"}
)  # TODO qué unidad es esta?
fig.set_xlabel("Frequency (Hz)", fontdict={"weight": "bold"})

# Remove legend title
handles, labels = fig.get_legend_handles_labels()
fig.legend(handles=handles[2:], labels=labels[2:])

plt.show()
# Out:
# /tmp/ipykernel_6203/638573422.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig.set_xticklabels([250, 500, 1000, 2000, 4000, 8000])

# %%
sns.set_context("talk")
fig = sns.boxplot(
    data=df_pointplots_ldl, x="Frequency", y="Db", hue="Group", dodge=True
)
fig.spines["top"].set_visible(False)
fig.spines["right"].set_visible(False)
fig.set_xticklabels([250, 500, 1000, 2000, 4000, 8000])
fig.set_ylabel(
    "Loudness Discomfort Level (Db)", fontdict={"weight": "bold", "fontsize": 14}
)  # TODO qué unidad es esta?
fig.set_xlabel("Frequency (Hz)", fontdict={"weight": "bold"})

# Remove legend title
handles, labels = fig.get_legend_handles_labels()
fig.legend(loc="center right", bbox_to_anchor=(1.4, 0.5))

plt.show()
# Out:
# /tmp/ipykernel_6203/2323406948.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig.set_xticklabels([250, 500, 1000, 2000, 4000, 8000])

# %%
sns.set_context("talk")
fig = sns.boxplot(
    data=df_pointplots_ldl, x="Frequency", y="Db", hue="Profile", dodge=True
)
fig.spines["top"].set_visible(False)
fig.spines["right"].set_visible(False)
fig.set_xticklabels([250, 500, 1000, 2000, 4000, 8000])
fig.set_ylabel(
    "Loudness Discomfort Level (Db)", fontdict={"weight": "bold", "fontsize": 14}
)  # TODO qué unidad es esta?
fig.set_xlabel("Frequency (Hz)", fontdict={"weight": "bold"})

# Remove legend title
handles, labels = fig.get_legend_handles_labels()
fig.legend(loc="center right", bbox_to_anchor=(1.4, 0.5))

plt.show()

# fig.savefig("drafts/gifted/FIG3.eps", bbox_inches="tight", format="eps")
# Out:
# /tmp/ipykernel_6203/370239334.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig.set_xticklabels([250, 500, 1000, 2000, 4000, 8000])

# %%
pg.mixed_anova(
    data=df_pointplots_ldl, dv="Db", between="Profile", within="Frequency", subject="ID"
)
# Out:
#         Source            SS  DF1  DF2            MS        F     p-unc  \
# 0      Profile  41372.101449    3   19  13790.700483  9.07440  0.000615
# 1    Frequency   2759.601449    5   95    551.920290  6.90148  0.000016
# 2  Interaction   1555.625823   15   95    103.708388  1.29682  0.219600
#
#    p-GG-corr       np2       eps sphericity   W-spher   p-spher
# 0        NaN  0.588951       NaN        NaN       NaN       NaN
# 1   0.000318  0.266451  0.665449      False  0.305624  0.049448
# 2        NaN  0.169960       NaN        NaN       NaN       NaN

# %%
ldl_posthoc = pg.pairwise_tests(
    data=df_pointplots_ldl,
    dv="Db",
    between="Profile",
    within="Frequency",
    subject="ID",
    correction=True,
    effsize="cohen",
    padjust="bonferroni",
)
ldl_posthoc
# Out:
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/parametric.py:257: RuntimeWarning: Degrees of freedom <= 0 for slice
#   vx, vy = x.var(ddof=1), y.var(ddof=1)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/effsize.py:802: RuntimeWarning: Degrees of freedom <= 0 for slice
#   poolsd = np.sqrt(((nx - 1) * x.var(ddof=1) + (ny - 1) * y.var(ddof=1)) / dof)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/effsize.py:802: RuntimeWarning: Degrees of freedom <= 0 for slice
#   poolsd = np.sqrt(((nx - 1) * x.var(ddof=1) + (ny - 1) * y.var(ddof=1)) / dof)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/parametric.py:257: RuntimeWarning: Degrees of freedom <= 0 for slice
#   vx, vy = x.var(ddof=1), y.var(ddof=1)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/effsize.py:802: RuntimeWarning: Degrees of freedom <= 0 for slice
#   poolsd = np.sqrt(((nx - 1) * x.var(ddof=1) + (ny - 1) * y.var(ddof=1)) / dof)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/effsize.py:802: RuntimeWarning: Degrees of freedom <= 0 for slice
#   poolsd = np.sqrt(((nx - 1) * x.var(ddof=1) + (ny - 1) * y.var(ddof=1)) / dof)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/parametric.py:257: RuntimeWarning: Degrees of freedom <= 0 for slice
#   vx, vy = x.var(ddof=1), y.var(ddof=1)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/effsize.py:802: RuntimeWarning: Degrees of freedom <= 0 for slice
#   poolsd = np.sqrt(((nx - 1) * x.var(ddof=1) + (ny - 1) * y.var(ddof=1)) / dof)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/parametric.py:257: RuntimeWarning: Degrees of freedom <= 0 for slice
#   vx, vy = x.var(ddof=1), y.var(ddof=1)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/effsize.py:802: RuntimeWarning: Degrees of freedom <= 0 for slice
#   poolsd = np.sqrt(((nx - 1) * x.var(ddof=1) + (ny - 1) * y.var(ddof=1)) / dof)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/parametric.py:257: RuntimeWarning: Degrees of freedom <= 0 for slice
#   vx, vy = x.var(ddof=1), y.var(ddof=1)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/effsize.py:802: RuntimeWarning: Degrees of freedom <= 0 for slice
#   poolsd = np.sqrt(((nx - 1) * x.var(ddof=1) + (ny - 1) * y.var(ddof=1)) / dof)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/parametric.py:257: RuntimeWarning: Degrees of freedom <= 0 for slice
#   vx, vy = x.var(ddof=1), y.var(ddof=1)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/effsize.py:802: RuntimeWarning: Degrees of freedom <= 0 for slice
#   poolsd = np.sqrt(((nx - 1) * x.var(ddof=1) + (ny - 1) * y.var(ddof=1)) / dof)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/parametric.py:257: RuntimeWarning: Degrees of freedom <= 0 for slice
#   vx, vy = x.var(ddof=1), y.var(ddof=1)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/effsize.py:802: RuntimeWarning: Degrees of freedom <= 0 for slice
#   poolsd = np.sqrt(((nx - 1) * x.var(ddof=1) + (ny - 1) * y.var(ddof=1)) / dof)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/parametric.py:257: RuntimeWarning: Degrees of freedom <= 0 for slice
#   vx, vy = x.var(ddof=1), y.var(ddof=1)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/effsize.py:802: RuntimeWarning: Degrees of freedom <= 0 for slice
#   poolsd = np.sqrt(((nx - 1) * x.var(ddof=1) + (ny - 1) * y.var(ddof=1)) / dof)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/parametric.py:257: RuntimeWarning: Degrees of freedom <= 0 for slice
#   vx, vy = x.var(ddof=1), y.var(ddof=1)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/effsize.py:802: RuntimeWarning: Degrees of freedom <= 0 for slice
#   poolsd = np.sqrt(((nx - 1) * x.var(ddof=1) + (ny - 1) * y.var(ddof=1)) / dof)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/parametric.py:257: RuntimeWarning: Degrees of freedom <= 0 for slice
#   vx, vy = x.var(ddof=1), y.var(ddof=1)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/effsize.py:802: RuntimeWarning: Degrees of freedom <= 0 for slice
#   poolsd = np.sqrt(((nx - 1) * x.var(ddof=1) + (ny - 1) * y.var(ddof=1)) / dof)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/parametric.py:257: RuntimeWarning: Degrees of freedom <= 0 for slice
#   vx, vy = x.var(ddof=1), y.var(ddof=1)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/effsize.py:802: RuntimeWarning: Degrees of freedom <= 0 for slice
#   poolsd = np.sqrt(((nx - 1) * x.var(ddof=1) + (ny - 1) * y.var(ddof=1)) / dof)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/parametric.py:257: RuntimeWarning: Degrees of freedom <= 0 for slice
#   vx, vy = x.var(ddof=1), y.var(ddof=1)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/effsize.py:802: RuntimeWarning: Degrees of freedom <= 0 for slice
#   poolsd = np.sqrt(((nx - 1) * x.var(ddof=1) + (ny - 1) * y.var(ddof=1)) / dof)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/parametric.py:257: RuntimeWarning: Degrees of freedom <= 0 for slice
#   vx, vy = x.var(ddof=1), y.var(ddof=1)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/effsize.py:802: RuntimeWarning: Degrees of freedom <= 0 for slice
#   poolsd = np.sqrt(((nx - 1) * x.var(ddof=1) + (ny - 1) * y.var(ddof=1)) / dof)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/parametric.py:257: RuntimeWarning: Degrees of freedom <= 0 for slice
#   vx, vy = x.var(ddof=1), y.var(ddof=1)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
#                Contrast Frequency         A         B Paired Parametric  \
# 0             Frequency         -  LDL_1000  LDL_2000   True       True
# 1             Frequency         -  LDL_1000   LDL_250   True       True
# 2             Frequency         -  LDL_1000  LDL_4000   True       True
# 3             Frequency         -  LDL_1000   LDL_500   True       True
# 4             Frequency         -  LDL_1000  LDL_8000   True       True
# 5             Frequency         -  LDL_2000   LDL_250   True       True
# 6             Frequency         -  LDL_2000  LDL_4000   True       True
# 7             Frequency         -  LDL_2000   LDL_500   True       True
# 8             Frequency         -  LDL_2000  LDL_8000   True       True
# 9             Frequency         -   LDL_250  LDL_4000   True       True
# 10            Frequency         -   LDL_250   LDL_500   True       True
# 11            Frequency         -   LDL_250  LDL_8000   True       True
# 12            Frequency         -  LDL_4000   LDL_500   True       True
# 13            Frequency         -  LDL_4000  LDL_8000   True       True
# 14            Frequency         -   LDL_500  LDL_8000   True       True
# 15              Profile         -        2e      H-AQ  False       True
# 16              Profile         -        2e        HA  False       True
# 17              Profile         -        2e        TD  False       True
# 18              Profile         -      H-AQ        HA  False       True
# 19              Profile         -      H-AQ        TD  False       True
# 20              Profile         -        HA        TD  False       True
# 21  Frequency * Profile  LDL_1000        2e      H-AQ  False       True
# 22  Frequency * Profile  LDL_1000        2e        HA  False       True
# 23  Frequency * Profile  LDL_1000        2e        TD  False       True
# 24  Frequency * Profile  LDL_1000      H-AQ        HA  False       True
# 25  Frequency * Profile  LDL_1000      H-AQ        TD  False       True
# 26  Frequency * Profile  LDL_1000        HA        TD  False       True
# 27  Frequency * Profile  LDL_2000        2e      H-AQ  False       True
# 28  Frequency * Profile  LDL_2000        2e        HA  False       True
# 29  Frequency * Profile  LDL_2000        2e        TD  False       True
# 30  Frequency * Profile  LDL_2000      H-AQ        HA  False       True
# 31  Frequency * Profile  LDL_2000      H-AQ        TD  False       True
# 32  Frequency * Profile  LDL_2000        HA        TD  False       True
# 33  Frequency * Profile   LDL_250        2e      H-AQ  False       True
# 34  Frequency * Profile   LDL_250        2e        HA  False       True
# 35  Frequency * Profile   LDL_250        2e        TD  False       True
# 36  Frequency * Profile   LDL_250      H-AQ        HA  False       True
# 37  Frequency * Profile   LDL_250      H-AQ        TD  False       True
# 38  Frequency * Profile   LDL_250        HA        TD  False       True
# 39  Frequency * Profile  LDL_4000        2e      H-AQ  False       True
# 40  Frequency * Profile  LDL_4000        2e        HA  False       True
# 41  Frequency * Profile  LDL_4000        2e        TD  False       True
# 42  Frequency * Profile  LDL_4000      H-AQ        HA  False       True
# 43  Frequency * Profile  LDL_4000      H-AQ        TD  False       True
# 44  Frequency * Profile  LDL_4000        HA        TD  False       True
# 45  Frequency * Profile   LDL_500        2e      H-AQ  False       True
# 46  Frequency * Profile   LDL_500        2e        HA  False       True
# 47  Frequency * Profile   LDL_500        2e        TD  False       True
# 48  Frequency * Profile   LDL_500      H-AQ        HA  False       True
# 49  Frequency * Profile   LDL_500      H-AQ        TD  False       True
# 50  Frequency * Profile   LDL_500        HA        TD  False       True
# 51  Frequency * Profile  LDL_8000        2e      H-AQ  False       True
# 52  Frequency * Profile  LDL_8000        2e        HA  False       True
# 53  Frequency * Profile  LDL_8000        2e        TD  False       True
# 54  Frequency * Profile  LDL_8000      H-AQ        HA  False       True
# 55  Frequency * Profile  LDL_8000      H-AQ        TD  False       True
# 56  Frequency * Profile  LDL_8000        HA        TD  False       True
#
#             T        dof alternative     p-unc    p-corr    p-adjust     BF10  \
# 0    2.098094  22.000000   two-sided  0.047602  0.714030  bonferroni    1.373
# 1    5.011512  22.000000   two-sided  0.000051  0.000769  bonferroni  496.859
# 2    1.997685  22.000000   two-sided  0.058264  0.873955  bonferroni    1.172
# 3    2.205762  22.000000   two-sided  0.038147  0.572211  bonferroni    1.637
# 4    3.758864  22.000000   two-sided  0.001084  0.016260  bonferroni   33.015
# 5    2.752257  22.000000   two-sided  0.011627  0.174406  bonferroni    4.326
# 6    0.743138  22.000000   two-sided  0.465261  1.000000  bonferroni    0.281
# 7    0.173009  22.000000   two-sided  0.864227  1.000000  bonferroni    0.222
# 8    3.108954  22.000000   two-sided  0.005117  0.076753  bonferroni    8.645
# 9   -1.868407  22.000000   two-sided  0.075081  1.000000  bonferroni    0.964
# 10  -3.510229  22.000000   two-sided  0.001975  0.029625  bonferroni   19.588
# 11   0.070045  22.000000   two-sided  0.944790  1.000000  bonferroni    0.219
# 12  -0.389142  22.000000   two-sided  0.700912  1.000000  bonferroni    0.234
# 13   2.921384  22.000000   two-sided  0.007907  0.118608  bonferroni    5.978
# 14   2.612046  22.000000   two-sided  0.015915  0.238722  bonferroni    3.333
# 15   3.906928   5.000000   two-sided  0.011330  0.045320  bonferroni    6.281
# 16   3.491414  14.898292   two-sided  0.003310  0.013241  bonferroni   11.578
# 17   6.416715   6.141431   two-sided  0.000616  0.002465  bonferroni  145.055
# 18        NaN   1.000000   two-sided       NaN       NaN  bonferroni      nan
# 19        NaN   1.000000   two-sided       NaN       NaN  bonferroni      nan
# 20   2.998629   9.404599   two-sided  0.014286  0.057144  bonferroni    5.251
# 21   3.525120   5.000000   two-sided  0.016827  0.403848  bonferroni    4.669
# 22   3.005220  10.472968   two-sided  0.012594  0.302257  bonferroni    5.597
# 23   5.646797   8.920350   two-sided  0.000325  0.007808  bonferroni    68.13
# 24        NaN   1.000000   two-sided       NaN       NaN  bonferroni      nan
# 25        NaN   1.000000   two-sided       NaN       NaN  bonferroni      nan
# 26   3.382282   8.755832   two-sided  0.008424  0.202187  bonferroni    9.056
# 27   2.835404   5.000000   two-sided  0.036443  0.874623  bonferroni    2.633
# 28   2.819957  12.617924   two-sided  0.014825  0.355796  bonferroni    4.294
# 29   5.160353   8.590982   two-sided  0.000689  0.016546  bonferroni   41.345
# 30        NaN   1.000000   two-sided       NaN       NaN  bonferroni      nan
# 31        NaN   1.000000   two-sided       NaN       NaN  bonferroni      nan
# 32   2.676148   9.624839   two-sided  0.023983  0.575591  bonferroni    3.394
# 33   2.581989   5.000000   two-sided  0.049313  1.000000  bonferroni     2.11
# 34   1.707691  14.703972   two-sided  0.108713  1.000000  bonferroni    1.089
# 35   5.307910   7.418054   two-sided  0.000923  0.022160  bonferroni    48.19
# 36        NaN   1.000000   two-sided       NaN       NaN  bonferroni      nan
# 37        NaN   1.000000   two-sided       NaN       NaN  bonferroni      nan
# 38   3.493177   9.835681   two-sided  0.005938  0.142513  bonferroni   10.644
# 39   0.000000   5.000000   two-sided  1.000000  1.000000  bonferroni    0.373
# 40   3.366880  14.999563   two-sided  0.004236  0.101670  bonferroni    9.576
# 41   5.513401   6.424808   two-sided  0.001193  0.028629  bonferroni   59.506
# 42        NaN   1.000000   two-sided       NaN       NaN  bonferroni      nan
# 43        NaN   1.000000   two-sided       NaN       NaN  bonferroni      nan
# 44   2.394586   9.154846   two-sided  0.039813  0.955505  bonferroni    2.369
# 45  10.246951   5.000000   two-sided  0.000152  0.003649  bonferroni  173.199
# 46   4.416864  11.971190   two-sided  0.000845  0.020280  bonferroni   49.741
# 47   6.693783   4.433421   two-sided  0.001780  0.042729  bonferroni  188.329
# 48        NaN   1.000000   two-sided       NaN       NaN  bonferroni      nan
# 49        NaN   1.000000   two-sided       NaN       NaN  bonferroni      nan
# 50   2.901993   8.239981   two-sided  0.019220  0.461288  bonferroni    4.596
# 51   4.152274   5.000000   two-sided  0.008890  0.213370  bonferroni    7.539
# 52   2.939814  13.929597   two-sided  0.010808  0.259398  bonferroni    5.093
# 53   5.040788   5.264510   two-sided  0.003428  0.082283  bonferroni    36.48
# 54        NaN   1.000000   two-sided       NaN       NaN  bonferroni      nan
# 55        NaN   1.000000   two-sided       NaN       NaN  bonferroni      nan
# 56   2.215933   9.131609   two-sided  0.053505  1.000000  bonferroni    1.908
#
#        cohen
# 0   0.191797
# 1   0.614128
# 2   0.237427
# 3   0.224552
# 4   0.496691
# 5   0.353415
# 6   0.055921
# 7   0.018068
# 8   0.298179
# 9  -0.261531
# 10 -0.360824
# 11  0.009120
# 12 -0.042000
# 13  0.227974
# 14  0.296862
# 15  1.594997
# 16  1.454341
# 17  4.088798
# 18       NaN
# 19       NaN
# 20  1.501126
# 21  1.439124
# 22  1.521248
# 23  3.382265
# 24       NaN
# 25       NaN
# 26  1.741300
# 27  1.157549
# 28  1.334814
# 29  3.129478
# 30       NaN
# 31       NaN
# 32  1.327759
# 33  1.054093
# 34  0.748957
# 35  3.301656
# 36       NaN
# 37       NaN
# 38  1.718727
# 39  0.000000
# 40  1.430194
# 41  3.494004
# 42       NaN
# 43       NaN
# 44  1.211354
# 45  4.183300
# 46  1.691283
# 47  4.433883
# 48       NaN
# 49       NaN
# 50  1.531120
# 51  1.695159
# 52  1.175691
# 53  3.271288
# 54       NaN
# 55       NaN
# 56  1.122092

# %% [markdown]
# ### Hearing Level (HL) between groups

# %% [markdown]
# #### Preprocessing
# dataset must be in melt form

# %%
df_pointplots.head(5)
# Out:
#    Código de participante Group  LDL_250  LDL_500  LDL_1000  LDL_2000  \
# 7                    AC01    HA     60.0     60.0      70.0      70.0
# 8                    AC02    HA     80.0    100.0      85.0      85.0
# 9                    AC03    HA     80.0    100.0      90.0      95.0
# 11                   AC05    HA     80.0     95.0     100.0     105.0
# 12                   AC06    HA     80.0    100.0     120.0     115.0
#
#     LDL_4000  LDL_8000 LDL_Ear  HL_250_R  ...  HL_4000_L  HL_8000_L  HL_250  \
# 7       50.0      55.0       L      20.0  ...       15.0       20.0    10.0
# 8       85.0      90.0       L      10.0  ...       10.0       15.0    10.0
# 9      100.0     100.0       L      20.0  ...        5.0        5.0    10.0
# 11     100.0      80.0       L       5.0  ...        5.0        5.0     5.0
# 12     115.0     100.0       L       0.0  ...        0.0      -10.0     5.0
#
#     HL_500  HL_1000  HL_2000  HL_4000  HL_8000  AQ_TOTAL  Profile
# 7     10.0     10.0     10.0     15.0     20.0       5.0       HA
# 8      5.0     10.0      5.0     10.0     15.0       6.0       2e
# 9     10.0      5.0      5.0      5.0      5.0       5.0       HA
# 11     5.0      0.0      5.0      5.0      5.0       7.0       2e
# 12     5.0      5.0     -5.0      0.0    -10.0       7.0       2e
#
# [5 rows x 29 columns]

# %%
# Split groups
df_pointplots_HA = df_pointplots[df_pointplots["Group"] == "HA"]
df_pointplots_control = df_pointplots[df_pointplots["Group"] == "Control"]

# Melt for HA
df_pointplots_HA = pd.melt(
    df_pointplots_HA,
    id_vars=["Código de participante", "AQ_TOTAL", "Profile"],
    value_vars=["HL_250", "HL_500", "HL_1000", "HL_2000", "HL_4000", "HL_8000"],
)
df_pointplots_HA["Group"] = "HA"

# Melt for control
df_pointplots_control = pd.melt(
    df_pointplots_control,
    id_vars=["Código de participante", "AQ_TOTAL", "Profile"],
    value_vars=["HL_250", "HL_500", "HL_1000", "HL_2000", "HL_4000", "HL_8000"],
)
df_pointplots_control["Group"] = "Control"

# Concat
df_pointplots_hl = pd.concat([df_pointplots_HA, df_pointplots_control])

df_pointplots_hl
# Out:
#    Código de participante  AQ_TOTAL Profile variable  value    Group
# 0                    AC01       5.0      HA   HL_250   10.0       HA
# 1                    AC02       6.0      2e   HL_250   10.0       HA
# 2                    AC03       5.0      HA   HL_250   10.0       HA
# 3                    AC05       7.0      2e   HL_250    5.0       HA
# 4                    AC06       7.0      2e   HL_250    5.0       HA
# ..                    ...       ...     ...      ...    ...      ...
# 31                  GC006       2.0      TD  HL_8000   15.0  Control
# 32                  GC007       4.0      TD  HL_8000    0.0  Control
# 33                  GC008       4.0      TD  HL_8000    5.0  Control
# 34                  GC010       4.0      TD  HL_8000    0.0  Control
# 35                  GC012       6.0    H-AQ  HL_8000    5.0  Control
#
# [138 rows x 6 columns]

# %%
df_pointplots_hl.columns = ["ID", "AQ", "Profile", "Frequency", "Db", "Group"]
df_pointplots_hl
# Out:
#        ID   AQ Profile Frequency    Db    Group
# 0    AC01  5.0      HA    HL_250  10.0       HA
# 1    AC02  6.0      2e    HL_250  10.0       HA
# 2    AC03  5.0      HA    HL_250  10.0       HA
# 3    AC05  7.0      2e    HL_250   5.0       HA
# 4    AC06  7.0      2e    HL_250   5.0       HA
# ..    ...  ...     ...       ...   ...      ...
# 31  GC006  2.0      TD   HL_8000  15.0  Control
# 32  GC007  4.0      TD   HL_8000   0.0  Control
# 33  GC008  4.0      TD   HL_8000   5.0  Control
# 34  GC010  4.0      TD   HL_8000   0.0  Control
# 35  GC012  6.0    H-AQ   HL_8000   5.0  Control
#
# [138 rows x 6 columns]

# %%
pg.mixed_anova(
    data=df_pointplots_hl, dv="Db", between="Group", within="Frequency", subject="ID"
)
# Out:
#         Source          SS  DF1  DF2          MS         F     p-unc  \
# 0        Group  178.475774    1   21  178.475774  1.027111  0.322373
# 1    Frequency  207.971014    5  105   41.594203  1.876700  0.104587
# 2  Interaction   64.863953    5  105   12.972791  0.585323  0.711164
#
#    p-GG-corr       np2      eps sphericity   W-spher   p-spher
# 0        NaN  0.046629      NaN        NaN       NaN       NaN
# 1   0.136112  0.082035  0.59952      False  0.145158  0.000425
# 2        NaN  0.027117      NaN        NaN       NaN       NaN

# %%
sns.lmplot(x="AQ", y="Db", hue="Group", col="Frequency", data=df_pointplots_hl)

# %%
# %%R -i df_pointplots_hl
#
# # Maximal random structure
# model <- lmer(Db ~ Group + Frequency + AQ + (1 + Group|ID) + (1 + Group|Frequency) + (1 + AQ|ID) + (1 + AQ|Frequency), data=df_pointplots_hl, REML=FALSE)
# null_model <- lmer(Db ~ Frequency + AQ + (1 + Group|ID) + (1 + Group|Frequency) + (1 + AQ|ID) + (1 + AQ|Frequency), data=df_pointplots_hl, REML=FALSE)
# #anova(model,null_model)
# summ(model, confint = TRUE)
# Out:
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/rpy2/robjects/pandas2ri.py:56: UserWarning: DataFrame contains duplicated elements in the index, which will lead to loss of the row names in the resulting data.frame
#   warnings.warn('DataFrame contains duplicated elements in the index, '
# MODEL INFO:
# Observations: 138
# Dependent Variable: Db
# Type: Mixed effects linear regression
#
# MODEL FIT:
# AIC = 895.33, BIC = 956.81
# Pseudo-R² (fixed effects) = 0.05
# Pseudo-R² (total) = 0.42
#
# FIXED EFFECTS:
# ---------------------------------------------------------------------------
#                           Est.    2.5%   97.5%   t val.         d.f.      p
# ---------------------- ------- ------- ------- -------- ------------ ------
# (Intercept)               4.38   -1.85   10.62     0.47        10.07   0.65
# GroupHA                   1.09   -2.91    5.10     0.33         7.11   0.75
# FrequencyHL_2000         -1.74   -4.37    0.89    -0.15   2336697.87   0.88
# FrequencyHL_250           0.22   -2.42    2.85     0.02   2336697.87   0.99
# FrequencyHL_4000         -2.17   -4.81    0.46    -0.18   2336697.87   0.85
# FrequencyHL_500          -0.22   -2.85    2.42    -0.02   2336697.87   0.99
# FrequencyHL_8000         -3.04   -5.68   -0.41    -0.26   2336697.87   0.80
# AQ                        0.08   -1.07    1.22     0.09         8.26   0.93
# ---------------------------------------------------------------------------
#
# p values calculated using Kenward-Roger standard errors and d.f.
#
# RANDOM EFFECTS:
# ---------------------------------------
#     Group       Parameter    Std. Dev.
# ------------- ------------- -----------
#      ID        (Intercept)     7.34
#      ID            AQ          0.93
#     ID.1       (Intercept)     0.00
#     ID.1         GroupHA       3.28
#   Frequency    (Intercept)     0.01
#   Frequency        AQ          0.00
#  Frequency.1   (Intercept)     0.00
#  Frequency.1     GroupHA       0.00
#   Residual                     4.56
# ---------------------------------------
#
# Grouping variables:
# -----------------------------
#    Group     # groups   ICC
# ----------- ---------- ------
#     ID          23      0.72
#  Frequency      6       0.00
# -----------------------------
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')

# %% [markdown]
# #### Plots

# %%
sns.set_context("talk")

fig = sns.pointplot(
    data=df_pointplots_hl,
    x="Frequency",
    y="Db",
    hue="Group",
    linestyles=["-", "--"],
    errorbar="se",
    dodge=True,
)
# plt.title("Hearing Level (Db) per Frequency (Hz)")
fig.set_xticklabels([250, 500, 1000, 2000, 4000, 8000])
# plt.xticks(['HL_250', 'HL_500', 'HL_1000', 'HL_2000', 'HL_4000', 'HL_8000'], [250, 'HL_500', 'HL_1000','HL_2000', 'HL_4000', 'HL_8000'])
fig.set_xlabel("Frequency (Hz)", fontdict={"weight": "bold"})
fig.set_ylabel("Hearing level (Db)", fontdict={"weight": "bold"})
fig.spines["top"].set_visible(False)
fig.spines["right"].set_visible(False)

handles, labels = fig.get_legend_handles_labels()
fig.legend(handles=handles[2:], labels=labels[2:])

plt.show()
# Out:
# /tmp/ipykernel_6203/504455651.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig.set_xticklabels([250, 500, 1000, 2000, 4000, 8000])

# %%
sns.set_context("talk")
fig = sns.boxplot(data=df_pointplots_hl, x="Frequency", y="Db", hue="Group")
fig.spines["top"].set_visible(False)
fig.spines["right"].set_visible(False)
fig.set_xticklabels([250, 500, 1000, 2000, 4000, 8000])
fig.set_ylabel(
    "Hearing Level (Db)", fontdict={"weight": "bold"}
)  # TODO qué unidad es esta?
fig.set_xlabel("Frequency (Hz)", fontdict={"weight": "bold"})

# Remove legend title
handles, labels = fig.get_legend_handles_labels()
fig.legend(loc="center right", bbox_to_anchor=(1.4, 0.5))

plt.show()
# fig.savefig("drafts/gifted/FIG1.eps", bbox_inches="tight", format="eps")
# Out:
# /tmp/ipykernel_6203/1671001067.py:5: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig.set_xticklabels([250, 500, 1000, 2000, 4000, 8000])

# %%
sns.set_context("talk")
fig = sns.boxplot(
    data=df_pointplots_hl, x="Frequency", y="Db", hue="Profile", dodge=True
)
fig.spines["top"].set_visible(False)
fig.spines["right"].set_visible(False)
fig.set_xticklabels([250, 500, 1000, 2000, 4000, 8000])
fig.set_ylabel(
    "Hearing Level (Db)", fontdict={"weight": "bold"}
)  # TODO qué unidad es esta?
fig.set_xlabel("Frequency (Hz)", fontdict={"weight": "bold"})

# Remove legend title
handles, labels = fig.get_legend_handles_labels()
fig.legend(loc="center right", bbox_to_anchor=(1.4, 0.5))

plt.show()
# Out:
# /tmp/ipykernel_6203/114465549.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig.set_xticklabels([250, 500, 1000, 2000, 4000, 8000])

# %% [markdown]
# ## Comparing means of OPI and TWI between HA and control
# - T-test OPI per group
# - OPI per group (boxplot)
# - T-test TWI per group
# - TWI per group (boxplot)

# %%
pg.pairwise_tests(
    data=df,
    dv="OPI",
    between="Group",
    effsize="cohen",
    correction=True,
    parametric=True,
)
# Out:
#   Contrast        A   B  Paired  Parametric        T       dof alternative  \
# 0    Group  Control  HA   False        True  0.63574  6.520437   two-sided
#
#     p-unc   BF10     cohen
# 0  0.5466  0.475  0.373673

# %%
sns.set_context("talk")
fig = sns.boxplot(data=df, x="Group", y="OPI")
fig.spines["top"].set_visible(False)
fig.spines["right"].set_visible(False)
fig.set_ylabel("OPI", fontdict={"weight": "bold"})  # TODO qué unidad es esta?
fig.set_xlabel("Group", fontdict={"weight": "bold"})

plt.show()

# %%
pg.pairwise_tests(
    data=df,
    dv="OPI",
    between="Profile",
    effsize="cohen",
    correction=True,
    parametric=True,
)
# Out:
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/parametric.py:257: RuntimeWarning: Degrees of freedom <= 0 for slice
#   vx, vy = x.var(ddof=1), y.var(ddof=1)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/effsize.py:802: RuntimeWarning: Degrees of freedom <= 0 for slice
#   poolsd = np.sqrt(((nx - 1) * x.var(ddof=1) + (ny - 1) * y.var(ddof=1)) / dof)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/effsize.py:802: RuntimeWarning: Degrees of freedom <= 0 for slice
#   poolsd = np.sqrt(((nx - 1) * x.var(ddof=1) + (ny - 1) * y.var(ddof=1)) / dof)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/parametric.py:257: RuntimeWarning: Degrees of freedom <= 0 for slice
#   vx, vy = x.var(ddof=1), y.var(ddof=1)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/effsize.py:802: RuntimeWarning: Degrees of freedom <= 0 for slice
#   poolsd = np.sqrt(((nx - 1) * x.var(ddof=1) + (ny - 1) * y.var(ddof=1)) / dof)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#   Contrast     A     B  Paired  Parametric         T       dof alternative  \
# 0  Profile    2e  H-AQ   False        True  0.282359  5.000000   two-sided
# 1  Profile    2e    HA   False        True -1.080807  8.473007   two-sided
# 2  Profile    2e    TD   False        True -1.137905  6.922069   two-sided
# 3  Profile  H-AQ    HA   False        True       NaN  1.000000   two-sided
# 4  Profile  H-AQ    TD   False        True       NaN  1.000000   two-sided
# 5  Profile    HA    TD   False        True -0.523977  5.105670   two-sided
#
#       p-unc   BF10     cohen
# 0  0.788983  0.386  0.115273
# 1  0.309584  0.634 -0.590603
# 2  0.293008   0.71 -0.714407
# 3       NaN    nan       NaN
# 4       NaN    nan       NaN
# 5  0.622238  0.491 -0.354286

# %%
sns.set_context("talk")
fig = sns.boxplot(data=df, x="Profile", y="OPI")
fig.spines["top"].set_visible(False)
fig.spines["right"].set_visible(False)
fig.set_ylabel("OPI", fontdict={"weight": "bold"})  # TODO qué unidad es esta?
fig.set_xlabel("Group", fontdict={"weight": "bold"})

plt.show()

# %%
pg.pairwise_tests(
    data=df,
    dv="TWI",
    between="Group",
    effsize="cohen",
    correction=True,
    parametric=True,
)
# Out:
#   Contrast        A   B  Paired  Parametric         T       dof alternative  \
# 0    Group  Control  HA   False        True -0.123954  7.701605   two-sided
#
#       p-unc   BF10     cohen
# 0  0.904526  0.416 -0.063932

# %%
sns.set_context("talk")
fig = sns.boxplot(data=df, x="Group", y="TWI")
fig.spines["top"].set_visible(False)
fig.spines["right"].set_visible(False)
fig.set_ylabel("TWI (ms)", fontdict={"weight": "bold"})  # TODO qué unidad es esta?
fig.set_xlabel("Group", fontdict={"weight": "bold"})

plt.show()

# %%
pg.pairwise_tests(
    data=df,
    dv="TWI",
    between="Profile",
    effsize="cohen",
    correction=True,
    parametric=True,
)
# Out:
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/parametric.py:257: RuntimeWarning: Degrees of freedom <= 0 for slice
#   vx, vy = x.var(ddof=1), y.var(ddof=1)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/effsize.py:802: RuntimeWarning: Degrees of freedom <= 0 for slice
#   poolsd = np.sqrt(((nx - 1) * x.var(ddof=1) + (ny - 1) * y.var(ddof=1)) / dof)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/effsize.py:802: RuntimeWarning: Degrees of freedom <= 0 for slice
#   poolsd = np.sqrt(((nx - 1) * x.var(ddof=1) + (ny - 1) * y.var(ddof=1)) / dof)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/parametric.py:257: RuntimeWarning: Degrees of freedom <= 0 for slice
#   vx, vy = x.var(ddof=1), y.var(ddof=1)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1114: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/pingouin/effsize.py:802: RuntimeWarning: Degrees of freedom <= 0 for slice
#   poolsd = np.sqrt(((nx - 1) * x.var(ddof=1) + (ny - 1) * y.var(ddof=1)) / dof)
# /home/renato/.virtualenvs/gifted/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#   Contrast     A     B  Paired  Parametric         T       dof alternative  \
# 0  Profile    2e  H-AQ   False        True  2.462614  5.000000   two-sided
# 1  Profile    2e    HA   False        True  0.539454  7.665004   two-sided
# 2  Profile    2e    TD   False        True  0.092023  8.804964   two-sided
# 3  Profile  H-AQ    HA   False        True       NaN  1.000000   two-sided
# 4  Profile  H-AQ    TD   False        True       NaN  1.000000   two-sided
# 5  Profile    HA    TD   False        True -0.409028  6.014668   two-sided
#
#       p-unc   BF10     cohen
# 0  0.057045  1.898  1.005358
# 1  0.604885  0.476  0.306581
# 2  0.928739  0.482  0.055418
# 3       NaN    nan       NaN
# 4       NaN    nan       NaN
# 5  0.696685  0.474 -0.250126

# %%
sns.set_context("talk")
fig = sns.boxplot(data=df, x="Profile", y="TWI")
fig.spines["top"].set_visible(False)
fig.spines["right"].set_visible(False)
fig.set_ylabel("TWI (ms)", fontdict={"weight": "bold"})  # TODO qué unidad es esta?
fig.set_xlabel("Group", fontdict={"weight": "bold"})

plt.show()

# %% [markdown]
# ## Compare differences between AQ scoring between experimental and control
# No significant differences

# %%
df_HA = df[df["Group"] == "HA"]
df_Control = df[df["Group"] == "Control"]


print("t test for AQ score")
display(pg.ttest(df_HA["AQ_TOTAL"], df_Control["AQ_TOTAL"]))
# Out:
# t test for AQ score
#                T       dof alternative     p-val         CI95%   cohen-d  \
# T-test  1.442583  8.803724   two-sided  0.183754  [-0.69, 3.1]  0.685267
#
#          BF10     power
# T-test  0.829  0.280536

# %% [markdown]
# ## Group Sigmoid plot

# %% [markdown]
# ### Preprocessing

# %%
df_sigmoid_fitted = pd.read_pickle("data/df_group_sigmoid_ha")

soas = [
    34.0,
    51.0,
    68.0,
    85.0,
    102.0,
    119.0,
    136.0,
    153.0,
    170.0,
    187.0,
    204.0,
    221.0,
    238.0,
    255.0,
    272.0,
]  # inter beep delay in experiment

# %%
# Generate the data for the plotsusing the fitted parameters
x = np.linspace(soas[0], soas[-1], 100)

index_of_control_group = 0
control = df_sigmoid_fitted.iloc[index_of_control_group].tolist()[1:-1]

index_of_HA_group = 1
ha = df_sigmoid_fitted.iloc[index_of_HA_group].tolist()[1:-1]

y_control = sig(x, *control)
y_ha = sig(x, *ha)

# Create a pandas DataFrame
df_control = pd.DataFrame({"x": x, "y": y_control})
df_ha = pd.DataFrame({"x": x, "y": y_ha})

# %% [markdown]
# ### Plot

# %%
ha_data = (
    df_sigmoid.query("Condition == 'HA'").groupby("SOA")["Illusion_count"].mean().values
    * 10
)
ha_data_sem = (
    df_sigmoid.query("Condition  == 'HA'").groupby("SOA")["Illusion_count"].sem().values
    * 10
)

control_data = (
    df_sigmoid.query("Condition == 'Control'")
    .groupby("SOA")["Illusion_count"]
    .mean()
    .values
    * 10
)
control_data_sem = (
    df_sigmoid.query("Condition == 'Control'")
    .groupby("SOA")["Illusion_count"]
    .sem()
    .values
    * 10
)

# %%
pg.mixed_anova(
    data=df_sigmoid,
    dv="Illusion_count",
    within="SOA",
    between="Condition",
    subject="Participant",
)
# Out:
#         Source           SS  DF1  DF2         MS          F         p-unc  \
# 0    Condition     3.052134    1   25   3.052134   0.043518  8.364430e-01
# 1          SOA  1249.219753   14  350  89.229982  31.967918  3.653870e-54
# 2  Interaction    33.981199   14  350   2.427229   0.869589  5.925639e-01
#
#       p-GG-corr       np2       eps sphericity   W-spher       p-spher
# 0           NaN  0.001738       NaN        NaN       NaN           NaN
# 1  1.188901e-17  0.561157  0.290018      False  0.000005  2.738634e-14
# 2           NaN  0.033614       NaN        NaN       NaN           NaN

# %%
dfi_posthoc = pg.pairwise_tests(
    data=df_sigmoid,
    dv="Illusion_count",
    between="Condition",
    within="SOA",
    subject="Participant",
    correction=True,
    effsize="cohen",
    padjust="bonferroni",
)

dfi_posthoc
# Out:
#             Contrast   SOA        A    B Paired Parametric         T  \
# 0                SOA     -      2.0  3.0   True       True -2.655343
# 1                SOA     -      2.0  4.0   True       True -4.248839
# 2                SOA     -      2.0  5.0   True       True -3.696786
# 3                SOA     -      2.0  6.0   True       True -2.210225
# 4                SOA     -      2.0  7.0   True       True -0.204782
# ..               ...   ...      ...  ...    ...        ...       ...
# 116  SOA * Condition  12.0  Control   HA  False       True  0.396556
# 117  SOA * Condition  13.0  Control   HA  False       True -0.218643
# 118  SOA * Condition  14.0  Control   HA  False       True  0.447444
# 119  SOA * Condition  15.0  Control   HA  False       True  1.656850
# 120  SOA * Condition  16.0  Control   HA  False       True  0.350614
#
#            dof alternative     p-unc    p-corr    p-adjust    BF10     cohen
# 0    26.000000   two-sided  0.013349  1.000000  bonferroni   3.658 -0.278602
# 1    26.000000   two-sided  0.000244  0.025589  bonferroni  119.16 -0.558212
# 2    26.000000   two-sided  0.001026  0.107688  bonferroni   33.31 -0.477622
# 3    26.000000   two-sided  0.036095  1.000000  bonferroni   1.615 -0.388247
# 4    26.000000   two-sided  0.839337  1.000000  bonferroni   0.208 -0.034716
# ..         ...         ...       ...       ...         ...     ...       ...
# 116   7.762966   two-sided  0.702372  1.000000  bonferroni   0.415  0.216627
# 117  12.990189   two-sided  0.830326  1.000000  bonferroni   0.399 -0.086405
# 118   7.562998   two-sided  0.667091  1.000000  bonferroni   0.421  0.250612
# 119   6.915872   two-sided  0.142040  1.000000  bonferroni    1.01  1.023987
# 120   8.471584   two-sided  0.734438  1.000000  bonferroni    0.41  0.177771
#
# [121 rows x 14 columns]

# %%
sup_table_1 = dfi_posthoc.query("Contrast == 'SOA * Condition'")[
    ["Contrast", "SOA", "A", "B", "T", "dof", "p-unc", "cohen"]
]
pg.print_table(sup_table_1, tablefmt="latex")
# Out:
# ==============
# POST HOC TESTS
# ==============
#
# \begin{tabular}{lrllrrrr}
# \hline
#  Contrast        &    SOA & A       & B   &      T &    dof &   p-unc &   cohen \\
# \hline
#  SOA * Condition &  2.000 & Control & HA  & -0.190 &  8.745 &   0.854 &  -0.094 \\
#  SOA * Condition &  3.000 & Control & HA  &  0.504 &  8.858 &   0.626 &   0.247 \\
#  SOA * Condition &  4.000 & Control & HA  & -0.385 &  9.198 &   0.709 &  -0.184 \\
#  SOA * Condition &  5.000 & Control & HA  & -0.523 &  9.579 &   0.613 &  -0.243 \\
#  SOA * Condition &  6.000 & Control & HA  & -0.254 &  8.699 &   0.805 &  -0.126 \\
#  SOA * Condition &  7.000 & Control & HA  & -0.038 &  8.432 &   0.971 &  -0.019 \\
#  SOA * Condition &  8.000 & Control & HA  &  0.004 &  8.322 &   0.997 &   0.002 \\
#  SOA * Condition &  9.000 & Control & HA  & -0.134 &  9.010 &   0.896 &  -0.065 \\
#  SOA * Condition & 10.000 & Control & HA  &  1.074 &  6.812 &   0.320 &   0.676 \\
#  SOA * Condition & 11.000 & Control & HA  &  0.473 &  8.137 &   0.649 &   0.248 \\
#  SOA * Condition & 12.000 & Control & HA  &  0.397 &  7.763 &   0.702 &   0.217 \\
#  SOA * Condition & 13.000 & Control & HA  & -0.219 & 12.990 &   0.830 &  -0.086 \\
#  SOA * Condition & 14.000 & Control & HA  &  0.447 &  7.563 &   0.667 &   0.251 \\
#  SOA * Condition & 15.000 & Control & HA  &  1.657 &  6.916 &   0.142 &   1.024 \\
#  SOA * Condition & 16.000 & Control & HA  &  0.351 &  8.472 &   0.734 &   0.178 \\
# \hline
# \end{tabular}

# %%
# Plot the sigmoid function
fig = sns.lineplot(data=df_control, x="x", y="y", label="Control")
fig = plt.scatter(soas, control_data)
fig = sns.lineplot(data=df_ha, x="x", y="y", label="HA")
fig = plt.scatter(soas, ha_data)

plt.xlabel("inter-beep delay (ms)")
plt.ylabel("% of perceived illusion")
plt.legend()
plt.show()

# fig.savefig("drafts/gifted/FIG4.eps", bbox_inches="tight", format="eps")

# %%
sns.lmplot(x="AQ", y="Illusion_count", hue="Condition", col="SOA", data=df_sigmoid)

# %%
# %%R -i df_sigmoid
#
# # Maximal random structure
# model <- lmer(Illusion_count ~ Condition + SOA + AQ + (1 + Condition|Participant) + (1 + Condition|SOA) + (1 + AQ|Participant) + (1 + AQ|SOA), data=df_sigmoid, REML=FALSE)
# null_model <- lmer(Illusion_count ~ SOA + AQ + (1 + Condition|Participant) + (1 + Condition|SOA) + (1 + AQ|Participant) + (1 + AQ|SOA), data=df_sigmoid, REML=FALSE)
# #anova(model,null_model)
# summ(model, confint = TRUE)
# Out:
# If summ is taking too long to run, try setting pvals = FALSE, t.df = 's' if
# you have the lmerTest package, or t.df = 'residual' (or some number).
# MODEL INFO:
# Observations: 405
# Dependent Variable: Illusion_count
# Type: Mixed effects linear regression
#
# MODEL FIT:
# AIC = 1694.74, BIC = 1762.80
# Pseudo-R² (fixed effects) = 0.35
# Pseudo-R² (total) = 0.57
#
# FIXED EFFECTS:
# -----------------------------------------------------------------
#                      Est.    2.5%   97.5%   t val.    d.f.      p
# ----------------- ------- ------- ------- -------- ------- ------
# (Intercept)          7.59    4.81   10.37     4.51   21.19   0.00
# ConditionHA          0.18   -1.85    2.20     0.15   10.54   0.89
# SOA                 -0.31   -0.39   -0.24    -6.80   15.21   0.00
# AQ                  -0.35   -0.82    0.11    -1.21   17.70   0.24
# -----------------------------------------------------------------
#
# p values calculated using Kenward-Roger standard errors and d.f.
#
# RANDOM EFFECTS:
# -----------------------------------------
#      Group        Parameter    Std. Dev.
# --------------- ------------- -----------
#   Participant    (Intercept)     2.62
#   Participant        AQ          0.59
#  Participant.1   (Intercept)     2.28
#  Participant.1   ConditionHA     1.01
#       SOA        (Intercept)     1.01
#       SOA            AQ          0.11
#      SOA.1       (Intercept)     0.12
#      SOA.1       ConditionHA     0.38
#    Residual                      1.65
# -----------------------------------------
#
# Grouping variables:
# -------------------------------
#     Group      # groups   ICC
# ------------- ---------- ------
#  Participant      27      0.43
#      SOA          15      0.33
# -------------------------------
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
# boundary (singular) fit: see help('isSingular')
